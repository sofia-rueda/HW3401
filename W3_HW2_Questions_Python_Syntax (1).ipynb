# %% [markdown]
# ## **Homework 2: Basic Markdown, Python Variables, Math Operations, User Input, and PEMDAS**
#
# This homework is designed to enhance your understanding of several fundamental concepts in Python and Jupyter Notebooks, including Markdown formatting, variable assignment, basic mathematics operations, handling user input, and the order of operations (PEMDAS).
#
# **Instructions:**
# - Answer each question in the notebook, using a Markdown cell for explanations and a code cell for Python code.
# - Ensure to execute your Python code to display the answers where applicable.

# %% [markdown]
# 1. Show what Markdown is used for in Jupyter Notebooks.

# %% [markdown]
# Markdown is a way to format text.

# %% [markdown]
# 2. Show how to format text to be bold in Markdown? Provide an example.

# %% [markdown]
# Cat (by adding double asteriks on each end of the word)
#
# **Cat**

# %% [markdown]
# 3. Create a Python variable named `a` and assign it the value 5.

# %% [markdown]
# **variable a equals to 5 and then print variable a**

# %%
a=5
print(a)
# Out:
# 5

# %% [markdown]
# 4. Perform an addition operation with any two numbers and display the result.

# %% [markdown]
# **used to variables, num1 and num2, assigned them both numbers, and then used another varaible, sum3, to add them**

# %%
num1=5
num2=10
sum3 =num1+num2
sum3
# Out:
# 15

# %% [markdown]
# 5. Divide 15 by 3 and show the result.

# %% [markdown]
# **simply entered 15/3 or assign the numbers to variables to solve**

# %%
15/3
# Out:
# 5.0

# %%
#or

num1=15
num2=3
quotient= (num1 / num2)
quotient
# Out:
# 5.0

# %% [markdown]
# 6. Use the `input()` function to ask the user for their name and then greet them.

# %% [markdown]
# **use input to get input.Python program that asks the user to enter their name, and then greet them**

# %%
name= input("Enter your name:")
print("Hello " +name+ ", nice to meet you")
# Out:
# Enter your name:Sofia
# Hello Sofia, nice to meet you

# %% [markdown]
# 7. Calculate the square of 7 and display the result.

# %% [markdown]
# **assigned the numbers to one variable**

# %%
result= 7*7
result
# Out:
# 49

# %% [markdown]
# 8. Ask the user for a number, multiply it by 2, and display the result.

# %% [markdown]
# **used input to ask the user for a number, assigned a variable to use and also the 'int' to establish the number as an integer**

# %%
num1= input("Enter a number:")
Num1=int(num1)
result= Num1*2
result
# Out:
# Enter a number:5
# 10

# %% [markdown]
# 9. Write a program that converts time from hours to seconds. Ask the user to input the time in hours, and then convert that time into seconds. Remember, 1 hour equals 3600 seconds.

# %% [markdown]
# **used input() and 'int' to assgin to one variable and the another varaible for the conversion and then print**

# %%
hrs=int(input("Enter time in hours:"))
sec=(hrs * 36000)
print("There is", sec ,"seconds in 5 hours.")
# Out:
# Enter time in hours:5
# There is 180000 seconds in 5 hours.

# %% [markdown]
# 10. Evaluate the expression `3 * (4 + 5) - 6 / 2` and display the result.

# %% [markdown]
# **made the varaible into a integer and entered the problem**

# %%
problem=int(3 * (4+5)-6/2)
problem
# Out:
# 24

# %% [markdown]
# 11. Assign the string 'Python' to a variable and print it.

# %% [markdown]
# **assigned the string 'Python' to a variable, string1 and print it**

# %%
string1= "Python"
print(string1)
# Out:
# Python

# %% [markdown]
# 12. Calculate the remainder when 22 is divided by 5.

# %% [markdown]
# **assigned both numbers to two variables and divided both variables to print remainder**

# %%
num1=22
num2=5
result= num1/num2
print(result)
# Out:
# 4.4

# %% [markdown]
# 13. Ask the user for two numbers, add them together, and display the sum.

# %% [markdown]
# **assigned two variables, made them into integers, used user input, added them by another variable, and displayed the sum**

# %%
num1=int(input("Enter number 1:"))
num2=int(input("Enter number 2:"))
sum= (num1 + num2)
sum
# Out:
# Enter number 1:5
# Enter number 2:5
# 10

# %% [markdown]
# 14. Write a Python code snippet that takes user input and prints the type of the input variable.

# %% [markdown]
# **assigned a variable to the users input and prints the type of the result of the input variable**

# %%
fruit= input("Enter a fruit:")
print(type(fruit))
# Out:
# Enter a fruit:mango
# <class 'str'>

# %% [markdown]
# 15. Calculate the product of 8 and 12, then subtract 4 and display the result.

# %% [markdown]
# **made three variables, assigned them integers and performed the problem to get the result**

# %%
num1= int(8)
num2=int(12)
num3=int(4)
result= ((num1*num2)-num3)
result
# Out:
# 92

# %% [markdown]
# 16. Explain the difference between `==` and `=` in Python.

# %% [markdown]
# **== is the equal operator, asking if both variables are equal to each other.**

# %%
x=5
y=7
x==y
# Out:
# False

# %% [markdown]
# **= is the transfer operator, x variable was 5 but now it switches to the y variable**

# %%
x=y
print(x)
# Out:
# 7

# %% [markdown]
# 17. Use Python to find the floor division of 100 by 11.

# %% [markdown]
# **rounds to the nearest integer**

# %%
100//11
# Out:
# 9

# %% [markdown]
# 18. Ask the user for a number, then calculate the square of that number.

# %% [markdown]
# **assigned one variable to a users input, convert it to a integer, used another variable to get the result**

# %%
num1= int(input("Enter a number:"))
s=(num1*num1)
s
# Out:
# Enter a number:5
# 25

# %% [markdown]
# 19. What does the `%` operator do in Python? Provide an example.

# %% [markdown]
# **% returns the remainder of dividing two numbers, see both examples**

# %%
test1= 9 % 3
test1
# Out:
# 0

# %%
test2= 3 % 2
test2
# Out:
# 1

# %% [markdown]
# 20. Using variables, demonstrate how to calculate and print the area of a rectangle (length * width).

# %% [markdown]
# **area of a rectangle is length times width, using two variables for the length and width, convert them to integers, used another variable for the area and print the resulf of the area**

# %%
length=int(30)
width=int(50)
area= length *width
print(area)
# Out:
# 1500
